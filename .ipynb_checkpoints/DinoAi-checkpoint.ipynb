# %% [markdown]
# ## Install and Import Dependencies

# %%
# !pip install -q torch torchvision torchaudio

# %%
# !pip install -q "stable-baselines3[extra]" "protobuf==3.20.*"

# %%
# !pip install -q mss pydirectinput pytesseract

# %%
# !pip install pydirectinput

# %%
# !brew install tesseract

# %%
# !pip install tesseract
# !pip install tesseract-ocr

# %%
# chrome://dino/

# %%
from mss import mss
from matplotlib import pyplot as plt
from gym import Env
from gym.spaces import Box, Discrete

import numpy as np
# import pydirectinput ??
import pytesseract
import time
import cv2

# %% [markdown]
# ## Building Environment

# %% [markdown]
# ### Create Environment

# %%
class WebGame(Env):
    #Setup the environment action and observation space
    def __init__(self):
        pass
    #called to do something in the game
    def step(self,action):
        pass
    #restart the game
    def reset(self):
        pass
    #visualize the game
    def render(self):
        pass
    #this closes down the observation
    def close(self):
        pass
    #get the part of the observation of the game that we want
    def get_observation(self):
        pass
    #get the "done" text using OCR
    def  get_done(self):
        pass

# %%
class WebGame(Env):
    def __init__(self):
        super().__init__()
        self.observation_space=Box(low=0, high=255, shape=(1,83,100),dtype=np.uint8)
        self.action_space=Discrete(3)

# %%
env=WebGame()
firstpic=env.observation_space.sample()[0]
plt.imshow(firstpic)

# %%
class WebGame(Env):
    def __init__(self):
        super().__init__()
        self.observation_space=Box(low=0, high=255, shape=(1,83,100),dtype=np.uint8)
        self.action_space=Discrete(3)
        
        self.cap=mss()
        self.game_location={"top":300,"left":0, "width":600, "height":500}
        self.done_location={"top":405,"left":63, "width":660, "height":70}
        
    def step(self,action):
        action_map={
            0:"space",
            1:"down",
            2:"no_op"
        }
        
        if action!=2:
            pyautogui.press(action_map[action])
            
        done,done_cap=self.get_done()
        new_observation=self.get_observation()
        reward=1 
        info={}
        return new_observation, reward, done, info
        
    def reset(self):
        time.sleep(1)
        pyautogui.click(x=150,y=150)
        pyautogui.press("space")
        return self.get_observation()
    
    def render(self):
        cv2.imshow("Game",np.array(self.cap.grab(self.game_location))[:,:,:3])
        if cv2.waitKey(1) & 0xFF==ord("q"):
            self.close()
            
    def close(self):
        cv2.destroyAllWindows()
        
    def get_observation(self):
        #get raw screen capture of the game 
        raw=np.array(self.cap.grab(self.game_location))[:,:,:3].astype(np.uint8)
        gray=cv2.cvtColor(raw,cv2.COLOR_BGR2GRAY)
        resized=cv2.resize(gray, (100,83))
        channel=np.reshape(resized, (1,83,100))
        return channel
    def get_done(self):
        done_cap=np.array(self.cap.grab(self.done_location))[:,:,:3].astype(np.uint8)
        done_strings=["GAME","GAHE"]
        
        #Apply OCR
        done=False
        res=pytesseract.image_to_string(done_cap)[:4]
        if res in done_strings:
            done=True
        
        return done,done_cap

# %%
env=WebGame()
print(env.get_observation()[0])
print(np.array(env.get_observation()).shape)
plt.imshow(np.array(env.get_observation()[0]))
plt.imshow(cv2.cvtColor(env.get_observation()[0],cv2.COLOR_BGR2RGB))
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# (1, 83, 100)

# %%
env=WebGame() # have to initialize the class first
plt.imshow(env.get_done())

# %%
env=WebGame() # have to initialize the class first
done, done_cap=env.get_done()
print(res)
print(done)
plt.imshow(done_cap)
# Out:
# GAME
# False

# %%
# !pip install pyobjc-core
# !pip install pyobjc-framework-Quartz
# !pip install AppKit
# !pip install PyUserinput
# !pip install pymouse
## ??

# %%
# !pip install pyautogui

# %%
import pyautogui

# %%
screenWidth, screenHeight = pyautogui.size()

# %%
screenWidth, screenHeight
# Out:
# (1440, 900)

# %%
pyautogui.press('esc')  # Press the Esc key. All key names are in pyautogui.KEY_NAMES

# %%
# pyautogui.KEY_NAMES

# %%
env=WebGame()
env.render()

# %%
env.close() # I cant close the render screen , maybe try it in vscode

# %%
env=WebGame()
env.reset()
# Out:
# array([[[255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 225, 248, 248],
#         [255, 255, 255, ..., 246, 246, 246],
#         [255, 255, 255, ..., 242, 242, 242]]], dtype=uint8)

# %% [markdown]
# ### Test Environment

# %%
env=WebGame()

# %%
obs=env.get_observation()

# %%
plt.imshow(obs[0])

# %%
#color conversion
plt.imshow(cv2.cvtColor(obs[0],cv2.COLOR_BGR2RGB))

# %%
done, done_cap=env.get_done()

# %%
done
# Out:
# True

# %%
plt.imshow(done_cap)

# %%
res
# Out:
# 'GAME'

# %%
pytesseract.image_to_string(done_cap)
# Out:
# 'GAME OVER\n'

# %%
for episode in range(10):
    env.reset()
    done=False
    total_reward=0
    
    while not done:
        obs, reward,done,info=env.step(env.action_space.sample())
        total_reward+=reward
    print(f"Total reward : {total_reward}")
# Out:
# Total reward : 24
# Total reward : 15
# Total reward : 19
# Total reward : 39
# Total reward : 28
# Total reward : 21
# Total reward : 17
# Total reward : 15
# Total reward : 16
# Total reward : 15

# %% [markdown]
# ## Train Model

# %% [markdown]
# ### Create Callback

# %%
#Import os for file path management
import os
#Import Base Callback for saving models
from stable_baselines3.common.callbacks import BaseCallback
#Check Environment
from stable_baselines3.common import env_checker

# %%
env=WebGame()
env_checker.check_env(env)

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/' #. is current directory, .. is parent directory pls rmb this
LOG_DIR = './logs/'
callback = TrainAndLoggingCallback(check_freq=1000, save_path=CHECKPOINT_DIR)

# %%
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq,save_path, verbose=1):
        super(TrainAndLoggingCallback,self).__init__(verbose)
        self.check_freq=check_freq
        self.save_path=save_path
        
    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
    def _on_step(self):
        if self.n_calls & self.check_freq==0:
            model_path=os.path.join(self.save_path,"best_model_{}".format(self.n_calls))
            self.model.save(model_path)
        return True

CHECKPOINT_DIR="./train/"
LOG_DIR="./logs/"
callback=TrainAndLoggingCallback(check_freq=1000,save_path=CHECKPOINT_DIR) # check freq should be lesser that total_timesteps in model.learn

# %% [markdown]
# ### Build DQN and Train

# %%
from stable_baselines3 import DQN #Deep-Q Network

# %%
env=WebGame()
model=DQN("CnnPolicy",env,tensorboard_log=LOG_DIR,verbose=1,buffer_size=12000,learning_starts=1000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1000,callback=callback) #should at least go up to 80000
# Out:
# Logging to ./logs/DQN_2

# %% [markdown]
# ## Test out Model

# %%
obs=env.reset()
obs
model.predict(obs)
# Out:
# (2, None)

# %%
for episode in range(1):
    obs=env.reset()
    done=False
    total_reward=0
    
    while not done:
        action,_=model.predict(obs)
        obs,reward,done,info=env.step(int(action))
        total_reward+=reward
    print(f"Score: {total_reward}")
#     time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/2b/8swfrzvj1b10sb2dt02_4g6c0000gn/T/ipykernel_30513/3765874553.py in <module>
#       6     while not done:
#       7         action,_=model.predict(obs)
# ----> 8         obs,reward,done,info=env.step(int(action))
#       9         total_reward+=reward
#      10     print(f"Score: {total_reward}")
#
# /var/folders/2b/8swfrzvj1b10sb2dt02_4g6c0000gn/T/ipykernel_30513/1004222613.py in step(self, action)
#      19             pyautogui.press(action_map[action])
#      20
# ---> 21         done,done_cap=self.get_done()
#      22         new_observation=self.get_observation()
#      23         reward=1
#
# /var/folders/2b/8swfrzvj1b10sb2dt02_4g6c0000gn/T/ipykernel_30513/1004222613.py in get_done(self)
#      52         #Apply OCR
#      53         done=False
# ---> 54         res=pytesseract.image_to_string(done_cap)[:4]
# ...

# %%
final_model=os.path.join("train","best_model_1030.zip")

# %%
# import pickle
model=DQN.load(os.path.join("train","best_model_88000"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/2b/8swfrzvj1b10sb2dt02_4g6c0000gn/T/ipykernel_30513/3032141975.py in <module>
#       1 # import pickle
# ----> 2 model=DQN.load(os.path.join("train","best_model_88000"))
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/stable_baselines3/common/base_class.py in load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     690
#     691         # Remove stored device information and replace with ours
# --> 692         if "policy_kwargs" in data:
#     693             if "device" in data["policy_kwargs"]:
#     694                 del data["policy_kwargs"]["device"]
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
file=pickle.load(open(final_model)) #???????
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/2b/8swfrzvj1b10sb2dt02_4g6c0000gn/T/ipykernel_30513/823986860.py in <module>
# ----> 1 file=pickle.load(open(final_model))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train/best_model_1030'

# %%
with open(final_model,"rb") as reader:
    features=pickle.load(reader)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /var/folders/2b/8swfrzvj1b10sb2dt02_4g6c0000gn/T/ipykernel_30513/1298246778.py in <module>
#       1 with open(final_model,"rb") as reader:
# ----> 2     features=pickle.load(reader)
#
# UnpicklingError: A load persistent id instruction was encountered,
# but no persistent_load function was specified.
